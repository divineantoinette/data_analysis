# %% [markdown]
# My First Program

# %%
#my first program
print("Hello World")
# Out:
# Hello World

# %%
print("Hello World")
# Out:
# Hello World

# %%
#printing my name
print("Divine Brabbs")
# Out:
# Divine Brabbs

# %%
#variables: A variable is a container that stores different data types
name = "Divine Brabbs"
print(name)
# Out:
# Divine Brabbs
